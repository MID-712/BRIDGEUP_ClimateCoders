# %% [markdown]
# # Reading in our Vietnam Data

# %% [markdown]
# Published Data - 'hon-tre2014.txt'

# %%
import pandas as pd
import os
#need this library to read file

# %%
DataPath = '/Users/brownscholar/Dropbox/BridgeUP_ClimateCoders/Data'
os.chdir(DataPath)
#get path 
df = pd.read_csv('hon-tre2014.txt', skiprows = 108 ,sep = '\t')
#read file

# %%
df.head()
#see data
# Out:
#    age_AD month  depth_mmBB  Sr/Ca-porBB  d18OporBB  depth_mmTN  Sr/Ca-porTN  \
# 0    2010   Nov         0.3        9.064     -6.447         NaN          NaN
# 1    2010   Oct         0.6        9.002     -6.430         NaN          NaN
# 2    2010   Sep         0.9        8.978     -6.059         NaN          NaN
# 3    2010   Aug         1.2        8.971     -5.981         NaN          NaN
# 4    2010   Jul         1.4        8.974     -6.099         NaN          NaN
#
#    d18OporTN
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.drop(labels = ['depth_mmBB', 'd18OporBB', 'depth_mmTN', 'd18OporTN'], axis = 1 )
#drop unecessary columns
# Out:
#      age_AD month  Sr/Ca-porBB  Sr/Ca-porTN
# 0      2010   Nov        9.064          NaN
# 1      2010   Oct        9.002          NaN
# 2      2010   Sep        8.978          NaN
# 3      2010   Aug        8.971          NaN
# 4      2010   Jul        8.974          NaN
# 5      2010   Jun        8.969          NaN
# 6      2010   May        8.966          NaN
# 7      2010   Apr        9.030          NaN
# 8      2010   Mar        9.123          NaN
# 9      2010   Feb        9.203          NaN
# 10     2010   Jan        9.210          NaN
# 11     2009   Dec        9.218          NaN
# 12     2009   Nov        9.148          NaN
# 13     2009   Oct        8.992          NaN
# 14     2009   Sep        8.923          NaN
# 15     2009   Aug        8.932          NaN
# 16     2009   Jul        8.953          NaN
# 17     2009   Jun        8.957          NaN
# 18     2009   May        9.013          NaN
# 19     2009   Apr        9.005          NaN
# ...

# %% [markdown]
# Unpublished Data that goes back to 1600s - 'HonTre_Vietnam_SrCa.xlsx'

# %%
Datapath = '/Users/brownscholar/Dropbox/BridgeUP_ClimateCoders/Data'
os.chdir(Datapath)
#get path 
df = pd.read_excel('HonTre_Vietnam_SrCa.xlsx')

# %%
df.head()
#see data
# Out:
#           Date  Month  Sr/Ca Comp
# 0  2010.871233     11       9.064
# 1  2010.787671     10       9.002
# 2  2010.704110      9       8.978
# 3  2010.620548      8       8.971
# 4  2010.535616      7       8.974

# %%
import matplotlib.pyplot as plt

# %%
date = df['Date']
sr_ca = df['Sr/Ca Comp']

# %%
plt.plot(date, sr_ca)
plt.xlabel("Date")
plt.ylabel("Sr/Ca Comp")
# Out:
# Text(0, 0.5, 'Sr/Ca Comp')

# %% [markdown]
# # Challenge

# %% [markdown]
# Dates are stored in a digital time format
#
# For example1880.5 = 1880 + ½ of a year = 06/1880 or June 1880
#
# Goal: Convert your date column into two separate columns of year and month

# %% [markdown]
# Come up with a mathematical formula to find the month corresponding to the date 1880.5

# %%
df['Date'],sep = "."
# Out:
#   File "<ipython-input-19-4a431e3d354e>", line 1
#     df['Date'],sep = ".",.head()
#                          ^
# SyntaxError: invalid syntax

# %%
df['Date'].head()
# Out:
# 0    2010.871233
# 1    2010.787671
# 2    2010.704110
# 3    2010.620548
# 4    2010.535616
# Name: Date, dtype: float64

# %%
df['Date'].loc[df['Month'] == 7]
# Out:
# 4       2010.535616
# 16      2009.535616
# 28      2008.535616
# 40      2007.535616
# 52      2006.535616
# 64      2005.535616
# 76      2004.535616
# 88      2003.535616
# 100     2002.535616
# 112     2001.535616
# 124     2000.535616
# 136     1999.535616
# 148     1998.535616
# 160     1997.535616
# 172     1996.535616
# 184     1995.535616
# 196     1994.535616
# 208     1993.535616
# 220     1992.535616
# 232     1991.535616
# 244     1990.535616
# 256     1989.535616
# 268     1988.535616
# 280     1987.535616
# 292     1986.535616
# 304     1985.535616
# 316     1984.535616
# 328     1983.535616
# 340     1982.535616
# 352     1981.535616
#            ...
# 4576    1629.535616
# 4588    1628.535616
# 4600    1627.535616
# 4612    1626.535616
# 4624    1625.535616
# 4636    1624.535616
# 4648    1623.535616
# 4660    1622.535616
# 4672    1621.535616
# 4684    1620.535616
# 4696    1619.535616
# 4708    1618.535616
# 4720    1617.535616
# 4732    1616.535616
# ...
